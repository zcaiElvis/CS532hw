# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
losses = np.loadtxt("results/losses_4.dat")

# %%
plt.plot(-np.log(np.abs(losses)))

# %%
plt.plot(losses)
# plt.ylim((-50000,10000))
